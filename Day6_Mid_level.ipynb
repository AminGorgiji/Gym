# %% [markdown]
# **Find Angle MBC**
#
# ![1440151155-10b2b748ee-rsz_1438840048-2cf71ed69d-findangle.png](data:image/png;base64,...)
#
#
# ABC is a right triangle, 90 degree at B.
#
# Point M is the midpoint of hypotenuse AC.
#
# You are given the lengths AB and BC.
#
# Your task is to find MBC (angle theta, as shown in the figure) in degrees.

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
import math
AB = int(input())
BC = int(input())
t = (math.atan(AB/BC))
t_d = round(math.degrees(t))
print(f"{t_d}{chr(176)}")
# Out:
# 10
# 10
# 45°
